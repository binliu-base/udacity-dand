# %%
import sys
import pickle
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data
import pandas as pd
# Out:
# /home/ros/anaconda2/envs/pose/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".
features_list = ['poi','salary'] # You will need to use more features

### Load the dictionary containing the dataset
with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

# %%
print('####### Data Exploration #########')
people = data_dict.keys()
print('Total number of data points: %d' % len(people))
POI_count = 0
for person in people:
    POI_count += data_dict[person]['poi']    
print('Number of flagged Persons of Interest: %d' % POI_count)
print('Number of people without POI flag: %d' % (len(people) - POI_count))

### Feature Exploration
all_features = data_dict['CORDES WILLIAM R'].keys()
print('Each person has %d features available' %  len(all_features))
# Out:
# ####### Data Exploration #########
# Total number of data points: 146
# Number of flagged Persons of Interest: 18
# Number of people without POI flag: 128
# Each person has 21 features available

# %%
df = pd.DataFrame(data_dict)
pd.set_option('display.width', 360)  
df
# Out:
#                                    ALLEN PHILLIP K BADUM JAMES P          BANNANTINE JAMES M BAXTER JOHN C       BAY FRANKLIN R BAZELIDES PHILIP J          BECK SALLY W      BELDEN TIMOTHY N BELFER ROBERT            BERBERIAN DAVID    ...               WASAFF GEORGE       WESTFAHL RICHARD K WHALEY DAVID A      WHALLEY LAWRENCE G       WHITE JR THOMAS E  \
# bonus                                      4175000           NaN                         NaN       1200000               400000                NaN                700000               5249999           NaN                        NaN    ...                      325000                      NaN            NaN                 3000000                  450000
# deferral_payments                          2869717        178980                         NaN       1295738               260455             684694                   NaN               2144013       -102500                        NaN    ...                      831299                      NaN            NaN                     NaN                     NaN
# deferred_income                           -3081055           NaN                       -5104      -1386055              -201641                NaN                   NaN              -2334434           NaN                        NaN    ...                     -583325                   -10800            NaN                     NaN                     NaN
# director_fees                                  NaN           NaN                         NaN           NaN                  NaN                NaN                   NaN                   NaN          3285                        NaN    ...                         NaN                      NaN            NaN                     NaN                     NaN
# email_address              phillip.allen@enron.com           NaN  james.bannantine@enron.com           NaN  frank.bay@enron.com                NaN  sally.beck@enron.com  tim.belden@enron.com           NaN  david.berberian@enron.com    ...     george.wasaff@enron.com  dick.westfahl@enron.com            NaN  greg.whalley@enron.com  thomas.white@enron.com
# exercised_stock_options                    1729541        257817                     4046157       6680544                  NaN            1599641                   NaN                953136          3285                    1624396    ...                     1668260                      NaN          98718                 3282960                 1297049
# expenses                                     13868          3486                       56301         11200               129142                NaN                 37172                 17355           NaN                      11892    ...                         NaN                    51870            NaN                   57838                   81353
# from_messages                                 2195           NaN                          29           NaN                  NaN                NaN                  4343                   484           NaN                        NaN    ...                          30                      NaN            NaN                     556                     NaN
# from_poi_to_this_person                         47           NaN                          39           NaN                  NaN                NaN                   144                   228           NaN                        NaN    ...                          22                      NaN            NaN                     186                     NaN
# from_this_person_to_poi                         65           NaN                           0           NaN                  NaN                NaN                   386                   108           NaN                        NaN    ...                           7                      NaN            NaN                      24                     NaN
# loan_advances                                  NaN           NaN                         NaN           NaN                  NaN                NaN                   NaN                   NaN           NaN                        NaN    ...                         NaN                      NaN            NaN                     NaN                     NaN
# long_term_incentive                         304805           NaN                         NaN       1586055                  NaN              93750                   NaN                   NaN           NaN                        NaN    ...                      200000                   256191            NaN                  808346                     NaN
# other                                          152           NaN                      864523       2660303                   69                874                   566                210698           NaN                        NaN    ...                        1425                   401130            NaN                  301026                 1085463
# poi                                          False         False                       False         False                False              False                 False                  True         False                      False    ...                       False                    False          False                   False                   False
# restricted_stock                            126027           NaN                     1757552       3942714               145796                NaN                126027                157569           NaN                     869220    ...                      388167                   384930            NaN                 2796177                13847074
# restricted_stock_deferred                  -126027           NaN                     -560222           NaN               -82782                NaN                   NaN                   NaN         44093                        NaN    ...                         NaN                      NaN            NaN                     NaN                     NaN
# salary                                      201955           NaN                         477        267102               239671              80818                231330                213999           NaN                     216582    ...                      259996                    63744            NaN                  510364                  317543
# shared_receipt_with_poi                       1407           NaN                         465           NaN                  NaN                NaN                  2639                  5521           NaN                        NaN    ...                         337                      NaN            NaN                    3920                     NaN
# to_messages                                   2902           NaN                         566           NaN                  NaN                NaN                  7315                  7991           NaN                        NaN    ...                         400                      NaN            NaN                    6019                     NaN
# total_payments                             4484442        182466                      916197       5634343               827696             860136                969068               5501630        102500                     228474    ...                     1034395                   762135            NaN                 4677574                 1934359
# total_stock_value                          1729541        257817                     5243487      10623258                63014            1599641                126027               1110705        -44093                    2493616    ...                     2056427                   384930          98718                 6079137                15144123
#
#                           WINOKUR JR. HERBERT S            WODRASKA JOHN WROBEL BRUCE          YEAGER F SCOTT YEAP SOON
# bonus                                       NaN                      NaN          NaN                     NaN       NaN
# deferral_payments                           NaN                      NaN          NaN                     NaN       NaN
# deferred_income                          -25000                      NaN          NaN                     NaN       NaN
# director_fees                            108579                      NaN          NaN                     NaN       NaN
# email_address                               NaN  john.wodraska@enron.com          NaN  scott.yeager@enron.com       NaN
# exercised_stock_options                     NaN                      NaN       139130                 8308552    192758
# expenses                                   1413                      NaN          NaN                   53947     55097
# from_messages                               NaN                      NaN          NaN                     NaN       NaN
# from_poi_to_this_person                     NaN                      NaN          NaN                     NaN       NaN
# from_this_person_to_poi                     NaN                      NaN          NaN                     NaN       NaN
# loan_advances                               NaN                      NaN          NaN                     NaN       NaN
# long_term_incentive                         NaN                      NaN          NaN                     NaN       NaN
# other                                       NaN                   189583          NaN                  147950       NaN
# poi                                       False                    False        False                    True     False
# restricted_stock                            NaN                      NaN          NaN                 3576206       NaN
# restricted_stock_deferred                   NaN                      NaN          NaN                     NaN       NaN
# salary                                      NaN                      NaN          NaN                  158403       NaN
# shared_receipt_with_poi                     NaN                      NaN          NaN                     NaN       NaN
# to_messages                                 NaN                      NaN          NaN                     NaN       NaN
# total_payments                            84992                   189583          NaN                  360300     55097
# total_stock_value                           NaN                      NaN       139130                11884758    192758
#
# [21 rows x 146 columns]

# %%
df.shape
# Out:
# (21, 146)
